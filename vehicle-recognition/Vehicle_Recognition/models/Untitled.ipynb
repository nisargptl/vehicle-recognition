# %%
import os

my_images = os.listdir('1_100')
my_images
# Out:
# ['GMC_Terrain_SUV_2012.jpg',
#  'AM_General_Hummer_SUV_2000.jpg',
#  'FIAT_500_Abarth_2012.jpg',
#  'Volvo_C30_Hatchback_2012.jpg',
#  'Ford_Fiesta_Sedan_2012.jpg',
#  'Chevrolet_Impala_Sedan_2007.jpg',
#  'Dodge_Durango_SUV_2012.jpg',
#  'Suzuki_Kizashi_Sedan_2012.jpg',
#  'BMW_Z4_Convertible_2012.jpg',
#  'Ford_Edge_SUV_2012.jpg',
#  'Audi_A5_Coupe_2012.jpg',
#  'Audi_S4_Sedan_2012.jpg',
#  'Dodge_Journey_SUV_2012.jpg',
#  'BMW_M3_Coupe_2012.jpg',
#  'Lamborghini_Reventon_Coupe_2008.jpg',
#  'Lamborghini_Aventador_Coupe_2012.jpg',
#  'Hyundai_Sonata_Hybrid_Sedan_2012.jpg',
#  'Cadillac_SRX_SUV_2012.jpg',
#  'Chrysler_Aspen_SUV_2009.jpg',
#  'Ferrari_458_Italia_Convertible_2012.jpg',
#  'Toyota_4Runner_SUV_2012.jpg',
#  'GMC_Acadia_SUV_2012.jpg',
#  'Dodge_Magnum_Wagon_2008.jpg',
#  'Ford_Freestar_Minivan_2007.jpg',
#  'BMW_1_Series_Convertible_2012.jpg',
#  'Volkswagen_Golf_Hatchback_1991.jpg',
#  'Toyota_Sequoia_SUV_2012.jpg',
#  'Audi_R8_Coupe_2012.jpg',
# ...

# %%
my_images1 = []
for image,j in zip(my_images,range(len(my_images))):
    image = str(image)
    image = 'models/1_100/'+image
    my_images1.append([])
    my_images1[j].append(image)
my_images1
# Out:
# [['models/1_100/models/1_100/GMC_Terrain_SUV_2012.jpg'],
#  ['models/1_100/models/1_100/AM_General_Hummer_SUV_2000.jpg'],
#  ['models/1_100/models/1_100/FIAT_500_Abarth_2012.jpg'],
#  ['models/1_100/models/1_100/Volvo_C30_Hatchback_2012.jpg'],
#  ['models/1_100/models/1_100/Ford_Fiesta_Sedan_2012.jpg'],
#  ['models/1_100/models/1_100/Chevrolet_Impala_Sedan_2007.jpg'],
#  ['models/1_100/models/1_100/Dodge_Durango_SUV_2012.jpg'],
#  ['models/1_100/models/1_100/Suzuki_Kizashi_Sedan_2012.jpg'],
#  ['models/1_100/models/1_100/BMW_Z4_Convertible_2012.jpg'],
#  ['models/1_100/models/1_100/Ford_Edge_SUV_2012.jpg'],
#  ['models/1_100/models/1_100/Audi_A5_Coupe_2012.jpg'],
#  ['models/1_100/models/1_100/Audi_S4_Sedan_2012.jpg'],
#  ['models/1_100/models/1_100/Dodge_Journey_SUV_2012.jpg'],
#  ['models/1_100/models/1_100/BMW_M3_Coupe_2012.jpg'],
#  ['models/1_100/models/1_100/Lamborghini_Reventon_Coupe_2008.jpg'],
#  ['models/1_100/models/1_100/Lamborghini_Aventador_Coupe_2012.jpg'],
# ...

# %%
with open('/home/nisarg/Desktop/sen project/vehicle-recognition/Vehicle_Recognition/models/images_path1.csv', 'w', newline=',') as file:
    writer = csv.writer(file)
    writer.writerows(my_images)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-1c4fb9cdb465> in <module>
# ----> 1 with open('/home/nisarg/Desktop/sen project/vehicle-recognition/Vehicle_Recognition/models/images_path1.csv', 'w', newline=',') as file:
#       2     writer = csv.writer(file)
#       3     writer.writerows(my_images)
#
# ValueError: illegal newline value: ,

# %%
import csv

# %%
with open('/home/nisarg/Desktop/sen project/vehicle-recognition/Vehicle_Recognition/models/images_path3.csv', 'w',newline='') as f:
      
    # using csv.writer method from CSV package
    write = csv.writer(f)
      
    write.writerow(my_images1)

# %%
with open('/home/nisarg/Desktop/sen project/vehicle-recognition/Vehicle_Recognition/models/car_image_names', 'w',newline='') as f:
      
    # using csv.writer method from CSV package
    reader = csv.reader(f)
      
    data = list(reader)
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-34-148761fbd27c> in <module>
#       4     reader = csv.reader(f)
#       5
# ----> 6     data = list(reader)
#
# UnsupportedOperation: not readable
